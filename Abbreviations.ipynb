# %%
import pandas as pd
from collections import Counter

# Load the Excel file
file_path = 'DataInput/Yan-Zheng-Compustat-Vars.xlsx'
xls = pd.ExcelFile(file_path)

# Load the data from the first sheet
data = pd.read_excel(file_path, sheet_name='Sheet1')

# Split words not only by space but also by hyphen
all_short_words_split = []
for phrase in data['shortername'].dropna():
    all_short_words_split.extend(phrase.replace('-', ' ').split())

# Get the most frequent words and their lengths
short_word_freq_split = Counter(all_short_words_split)
short_word_freq_split_df = pd.DataFrame(short_word_freq_split.items(), columns=['Word', 'Frequency'])
short_word_freq_split_df['Length'] = short_word_freq_split_df['Word'].apply(len)

# Sort by length and frequency
short_word_freq_split_sorted = short_word_freq_split_df.sort_values(by=['Length', 'Frequency'], ascending=[False, False])

# Define a function to create a dictionary of abbreviations for both uppercase and lowercase versions
def create_abbreviations_dict(abbreviations):
    abbreviations_case_sensitive = {}
    for key, value in abbreviations.items():
        abbreviations_case_sensitive[key] = value
        abbreviations_case_sensitive[key.lower()] = value.lower()
        abbreviations_case_sensitive[key.capitalize()] = value.capitalize()
    return abbreviations_case_sensitive

# Existing abbreviations
abbreviations = {
    'Depreciation': 'Depr',
    'Inventories': 'Inv',
    'investments': 'Invest',
    'liabilities': 'Liab',
    'activities': 'Act',
    'operations': 'Ops',
    'construction': 'Constr',
    'improvement': 'Improv',
    'administration': 'Admin',
    'extraordinary': 'Extraord',
    'compensation': 'Comp',
    'acquisitions': 'Acq',
    'amortization': 'Amort',
    'nonrecurring': 'Nonrec',
    'discontinued': 'Discont',
    'contribution': 'Contrib',
    'restatement': 'Restate',
    'adjustments': 'Adjust',
    'Convertible': 'Conv',
    'equivalents': 'Equiv',
    'subsidiaries': 'Subs',
    'Market': 'Mkt',
    'changes': 'chg',
#     'Current': 'Cur',
#     'assets': 'asst',
#     'other': 'oth',
#     'total': 'ttl',
    'Accounting': 'Accg',
    'Average': 'Avg',
    'changes': 'chgs',
    'change': 'chg',
    'subordinated': 'subord',
    'convertible': 'convert',
    'Current': 'Curr',
#     'assets': 'asst',
#     'other': 'oth',
#     'total': 'ttl',
    'Equity': 'Eqty',
    'income': 'inc',
#     'issuance': 'iss',
#     'retained': 'ret',
#     'earnings': 'earngs',
#     'restatement': 'restmnt',
    'operating': 'oper',
    'expenses': 'expns',
#     'repurchase': 'repurc'
}

# Create case-sensitive abbreviations dictionary
abbreviations_case_sensitive = create_abbreviations_dict(abbreviations)

# Create a new column with abbreviated words
def abbreviate_words(phrase, abbreviations):
    words = phrase.replace('-', ' ').split()
    abbreviated_words = []
    for word in words:
        if word in abbreviations:
            abbreviated_words.append(abbreviations[word])
        elif word.lower() in abbreviations:
            # Preserve the case of the word while using the abbreviation
            if word.islower():
                abbreviated_words.append(abbreviations[word.lower()])
            elif word.istitle():
                abbreviated_words.append(abbreviations[word.lower()].capitalize())
            elif word.isupper():
                abbreviated_words.append(abbreviations[word.lower()].upper())
        else:
            abbreviated_words.append(word)
    return ' '.join(abbreviated_words)

data['shortername'] = data['shortername'].apply(lambda x: abbreviate_words(x, abbreviations_case_sensitive))

# %%
abbreviations_case_sensitive
# Out:
# {'Depreciation': 'Depr',
#  'depreciation': 'depr',
#  'Inventories': 'Inv',
#  'inventories': 'inv',
#  'investments': 'invest',
#  'Investments': 'Invest',
#  'liabilities': 'liab',
#  'Liabilities': 'Liab',
#  'activities': 'act',
#  'Activities': 'Act',
#  'operations': 'ops',
#  'Operations': 'Ops',
#  'construction': 'constr',
#  'Construction': 'Constr',
#  'improvement': 'improv',
#  'Improvement': 'Improv',
#  'administration': 'admin',
#  'Administration': 'Admin',
#  'extraordinary': 'extraord',
#  'Extraordinary': 'Extraord',
#  'compensation': 'comp',
#  'Compensation': 'Comp',
#  'acquisitions': 'acq',
#  'Acquisitions': 'Acq',
#  'amortization': 'amort',
#  'Amortization': 'Amort',
#  'nonrecurring': 'nonrec',
#  'Nonrecurring': 'Nonrec',
#  'discontinued': 'discont',
#  'Discontinued': 'Discont',
#  'contribution': 'contrib',
#  'Contribution': 'Contrib',
#  'restatement': 'restate',
#  'Restatement': 'Restate',
#  'adjustments': 'adjust',
#  'Adjustments': 'Adjust',
#  'Convertible': 'Convert',
#  'convertible': 'convert',
#  'equivalents': 'equiv',
#  'Equivalents': 'Equiv',
#  'subsidiaries': 'subs',
#  'Subsidiaries': 'Subs',
#  'Market': 'Mkt',
#  'market': 'mkt',
#  'changes': 'chgs',
#  'Changes': 'Chgs',
#  'Accounting': 'Accg',
#  'accounting': 'accg',
#  'Average': 'Avg',
#  'average': 'avg',
#  'change': 'chg',
#  'Change': 'Chg',
#  'subordinated': 'subord',
#  'Subordinated': 'Subord',
#  'Current': 'Curr',
#  'current': 'curr',
#  'Equity': 'Eqty',
#  'equity': 'eqty',
#  'income': 'inc',
#  'Income': 'Inc',
#  'operating': 'oper',
#  'Operating': 'Oper',
#  'expenses': 'expns',
#  'Expenses': 'Expns'}

# %%
abbreviations_case_sensitive
# Out:
# {'Depreciation': 'Depr',
#  'depreciation': 'depr',
#  'Inventories': 'Inv',
#  'inventories': 'inv',
#  'investments': 'invest',
#  'Investments': 'Invest',
#  'liabilities': 'liab',
#  'Liabilities': 'Liab',
#  'activities': 'act',
#  'Activities': 'Act',
#  'operations': 'ops',
#  'Operations': 'Ops',
#  'construction': 'constr',
#  'Construction': 'Constr',
#  'improvement': 'improv',
#  'Improvement': 'Improv',
#  'administration': 'admin',
#  'Administration': 'Admin',
#  'extraordinary': 'extraord',
#  'Extraordinary': 'Extraord',
#  'compensation': 'comp',
#  'Compensation': 'Comp',
#  'acquisitions': 'acq',
#  'Acquisitions': 'Acq',
#  'amortization': 'amort',
#  'Amortization': 'Amort',
#  'nonrecurring': 'nonrec',
#  'Nonrecurring': 'Nonrec',
#  'discontinued': 'discont',
#  'Discontinued': 'Discont',
#  'contribution': 'contrib',
#  'Contribution': 'Contrib',
#  'restatement': 'restate',
#  'Restatement': 'Restate',
#  'adjustments': 'adjust',
#  'Adjustments': 'Adjust',
#  'Convertible': 'Convert',
#  'convertible': 'convert',
#  'equivalents': 'equiv',
#  'Equivalents': 'Equiv',
#  'subsidiaries': 'subs',
#  'Subsidiaries': 'Subs',
#  'Market': 'Mkt',
#  'market': 'mkt',
#  'changes': 'chgs',
#  'Changes': 'Chgs',
#  'Accounting': 'Accg',
#  'accounting': 'accg',
#  'Average': 'Avg',
#  'average': 'avg',
#  'change': 'chg',
#  'Change': 'Chg',
#  'subordinated': 'subord',
#  'Subordinated': 'Subord',
#  'Current': 'Curr',
#  'current': 'curr',
#  'Equity': 'Eqty',
#  'equity': 'eqty',
#  'income': 'inc',
#  'Income': 'Inc',
#  'operating': 'oper',
#  'Operating': 'Oper',
#  'expenses': 'expns',
#  'Expenses': 'Expns'}

# %%
data.head(30)
# Out:
#       id acronym                                           longname  \
# 0    1.0   ACCHG             Accounting changes – cumulative effect
# 1    2.0     ACO                         Current assets other total
# 2    3.0    ACOX                        Current assets other sundry
# 3    4.0     ACT                             Current assets – total
# 4    5.0      AM                        Amortization of intangibles
# 5    6.0      AO                                     Assets – other
# 6    7.0  AOLOCH            Assets and liabilities other net change
# 7    8.0     AOX                            Assets – other – sundry
# 8    9.0      AP                           Accounts payable – trade
# 9   10.0  APALCH  Accounts payable & accrued liabilities increas...
# 10  11.0     AQC                                       Acquisitions
# 11  12.0     AQI                   Acquisitions income contribution
# 12  13.0     AQS                    Acquisitions sales contribution
# 13  14.0      AT                                     Assets – total
# 14  15.0    BAST                       Average short-term borrowing
# 15  16.0    CAPS              Capital surplus/share premium reserve
# 16  17.0    CAPX                                Capital expenditure
# 17  18.0   CAPXV                 Capital expenditure PPE schedule V
# 18  19.0     CEQ                     Common/ordinary equity – total
# 19  20.0    CEQL                    Common equity liquidation value
# 20  21.0    CEQT                             Common equity tangible
# 21  22.0      CH                                               Cash
# 22  23.0     CHE                    Cash and short-term investments
# 23  24.0   CHECH        Cash and cash equivalents increase/decrease
# 24  25.0    CLD2               Capitalized leases – due in 2nd year
# 25  26.0    CLD3               Capitalized leases – due in 3rd year
# 26  27.0    CLD4               Capitalized leases – due in 4th year
# 27  28.0    CLD5               Capitalized leases – due in 5th year
# 28  29.0    COGS                                 Cost of goods sold
# 29  30.0    CSTK                    Common/ordinary stock (capital)
#
#                            shortername  length  In YZ Table A.1  \
# 0          Accg chgs cumulative effect      36                1
# 1              Curr assets other total      26                1
# 2             Curr assets other sundry      24                1
# 3                          Curr assets      15                1
# 4                 Amort of intangibles      27                1
# 5                         Assets other      12                1
# 6        Assets and liab other net chg      39                1
# 7                  Assets other sundry      19                1
# 8               Accounts payable trade      22                1
# 9                   Payable & liab chg      28                1
# 10                                 Acq      12                1
# 11                     Acq inc contrib      32                1
# 12                   Acq sales contrib      31                1
# 13                              Assets       7                1
# 14            Avg short term borrowing      28                1
# 15                 Cap surplus reserve      19                1
# 16                 Capital expenditure      19                1
# 17                     Capex PPE sch V      15                1
# 18                         Common eqty      13                1
# 19                      Eqty liq value      16                1
# 20                Common eqty tangible      22                1
# 21                                Cash       4                1
# 22                    Cash & ST invest      21                1
# 23             Cash and cash equiv chg      32                1
# 24  Capitalized leases due in 2nd year      34                1
# 25  Capitalized leases due in 3rd year      34                1
# 26  Capitalized leases due in 4th year      34                1
# 27  Capitalized leases due in 5th year      34                1
# 28                  Cost of goods sold      18                1
# 29                        Common stock      12                1
#
#     In YZ Table A.2
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# 5               NaN
# 6               NaN
# 7               NaN
# 8               NaN
# 9               NaN
# 10              NaN
# 11              NaN
# 12              NaN
# 13              NaN
# 14              NaN
# 15              NaN
# 16              NaN
# 17              NaN
# 18              NaN
# 19              NaN
# 20              NaN
# 21              NaN
# 22              NaN
# 23              NaN
# 24              NaN
# 25              NaN
# 26              NaN
# 27              NaN
# 28              NaN
# 29              NaN

# %%
# Save the updated DataFrame to a new Excel file
output_file_path = 'DataInput/Updated_Yan-Zheng-Compustat-Vars.xlsx'
data.to_excel(output_file_path, index=False)
